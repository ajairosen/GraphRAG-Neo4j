# %% [markdown]
# ### Import Libs and load creds

# %%
import os
import json
from typing import List
from langchain_groq import ChatGroq
import pandas as pd
# from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_community.graphs import Neo4jGraph
from dotenv import load_dotenv
from pydantic import BaseModel,Field


llm = ChatGroq(api_key=os.getenv("GROQ_API_KEY"),
                 model="llama3-8b-8192"
                 
                )

neo4j_url = os.getenv("NEO4J_URI")
neo4j_user = os.getenv("NEO4J_USERNAME")
neo4j_password = os.getenv("NEO4J_PASSWORD")
graph = Neo4jGraph(url=neo4j_url,username=neo4j_user,password=neo4j_password,sanitize=True,enhanced_schema=True)
# Out:
# C:\Users\COMP\AppData\Local\Temp\ipykernel_15036\3675335738.py:20: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-neo4j package and should be used instead. To use it run `pip install -U :class:`~langchain-neo4j` and import as `from :class:`~langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(url=neo4j_url,username=neo4j_user,password=neo4j_password,sanitize=True,enhanced_schema=True)
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"

# %%
llm.invoke("Hi, explain me about cypher query language").content
# Out:
# 'Cypher is a query language specifically designed for graph databases, such as Neo4j. It\'s used to retrieve, manipulate, and analyze data stored in a graph structure. Here\'s an overview of Cypher:\n\n**What is Cypher?**\n\nCypher is a declarative language, which means you specify what you want to retrieve or manipulate, rather than how to do it. It\'s similar to SQL (Structured Query Language) for relational databases, but designed for graph databases.\n\n**Cypher syntax**\n\nCypher queries consist of a series of clauses, which are used to specify the query\'s intent. The basic syntax is as follows:\n```cypher\nMATCH (pattern) [WITH clause] [RETURN clause]\n```\nHere:\n\n* `MATCH` clause: Specifies the pattern to match in the graph.\n* `WITH` clause (optional): Allows you to alias or manipulate the matched nodes or relationships.\n* `RETURN` clause: Specifies the data to be returned.\n\n**Cypher patterns**\n\nCypher patterns are used to specify the relationships between nodes in the graph. There are several types of patterns:\n\n* `node`: Matches a single node.\n* `rel`: Matches a relationship between two nodes.\n* `path`: Matches a sequence of relationships between nodes.\n* `node(n)` : Matches a node with the given label and properties.\n\n**Cypher clauses**\n\nHere are some common Cypher clauses:\n\n* `MATCH` clause: As mentioned earlier, specifies the pattern to match.\n* `WHERE` clause: Filters the matched nodes or relationships based on conditions.\n* `WITH` clause: Aliases or manipulates the matched nodes or relationships.\n* `RETURN` clause: Specifies the data to be returned.\n* `CREATE` clause: Creates new nodes or relationships.\n* `MERGE` clause: Merges two nodes or relationships.\n\n**Cypher functions**\n\nCypher provides several built-in functions to perform various operations, such as:\n\n* `id()` : Returns the ID of a node.\n* `labels()` : Returns the labels of a node.\n* `relationships()` : Returns the relationships of a node.\n* `size()` : Returns the number of elements in a collection.\n* `collect()` : Aggregates a collection.\n\n**Cypher examples**\n\nHere are a few examples to get you started:\n\n* Retrieve all nodes with the label "Person":\n```cypher\nMATCH (p:Person) RETURN p\n```\n* Retrieve all relationships between nodes with the label "Friend":\n```cypher\nMATCH (a:Person)-[r:FRIEND]->(b:Person) RETURN r\n```\n* Create a new node with the label "Book" and properties:\n```cypher\nCREATE (book:Book {title: "The Great Gatsby", author: "F. Scott Fitzgerald"})\n```\n* Merge two nodes with the same label and properties:\n```cypher\nMERGE (a:Person {name: "John"}) MERGE (b:Person {name: "John"}) ON CREATE SET a = b\n```\nThese are just a few examples of what you can do with Cypher. If you\'re interested in learning more, I recommend checking out the official Neo4j documentation and tutorials.'

# %% [markdown]
# ### Pydantic class model

# %%
class Question(BaseModel):
    questions: List[str] = Field(
        description="List of relevant questions for the particular graph schema. Make sure that questions can be answered with information from the schema and that the questions are diverse as possible. Make sure that the schema and the example values contains the information that can answer the questions! Do not ask questions that cannot be answered based on the provided schema. For example, if no information about subtitles can be found in the graph, don't ask any information about subtitles. Make sure to always limit the results to less than 10 results by saying 3 users, or top 5 movies, or similar."
    )

structured_llm = llm.with_structured_output(Question)

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import (
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)


system_prompt = """Your task is to generate 1000 questions that are directly related to a specific graph schema in Neo4j. Each question should target distinct aspects of the schema, such as relationships between nodes, properties of nodes, or characteristics of node types. Ensure that the questions vary in complexity, covering basic, intermediate, and advanced queries.

Avoid ambiguous questions. For clarity, an ambiguous question is one that can be interpreted in multiple ways or does not have a straightforward answer based on the schema. For example, avoid asking, "What is related to this?" without specifying the node type or relationship.
Please design each question to yield a limited number of results, specifically between 10 to 50 results. This will ensure that the queries are precise and suitable for detailed analysis and training.
The goal of these questions is to create a dataset for training AI models to convert natural language queries into Cypher queries effectively.
It is vital that the database contains information that can answer the question!
Make sure to generate 1000 questions!"""

default_prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessagePromptTemplate.from_template(
            f"{system_prompt} Follow these instructions create minimum 100 possible questions: {{instructions}}"
        ),
        HumanMessagePromptTemplate.from_template(
            "Make sure to create questions for the following graph schema:{input}\n Here are some example nodes and relationship values: {values}. Don't use any values that aren't found in the schema or in provided values. Also, do not ask questions that there is no way to answer based on the schema or provided example values. Don't include question index or the sequence of the question in the list. Make sure your question is complete and clear"
        ),
    ]
)

chain = default_prompt | structured_llm

# %% [markdown]
# ### Specifying query types using dictionary

# %%
query_types = {
    "Simple Retrieval Queries": "These queries focus on basic data extraction, retrieving nodes or relationships based on straightforward criteria such as labels, properties, or direct relationships. Examples include fetching all nodes labeled as 'Person' or retrieving relationships of a specific type like 'EMPLOYED_BY'. Simple retrieval is essential for initial data inspections and basic reporting tasks. Always limit the number of results if more than one row is expected from the questions by saying 'first 3' or 'top 5' elements",
    "Complex Retrieval Queries": "These advanced queries use the rich pattern-matching capabilities of Cypher to handle multiple node types and relationship patterns. They involve sophisticated filtering conditions and logical operations to extract nuanced insights from interconnected data points. An example could be finding all 'Person' nodes who work in a 'Department' with over 50 employees and have at least one 'REPORTS_TO' relationship. Always limit the number of results if more than one row is expected from the questions by saying 'first 3' or 'top 5' elements",
    "Simple Aggregation Queries": "Simple aggregation involves calculating basic statistical metrics over properties of nodes or relationships, such as counting the number of nodes, averaging property values, or determining maximum and minimum values. These queries summarize data characteristics and support quick analytical conclusions. Always limit the number of results if more than one row is expected from the questions by saying 'first 3' or 'top 5' elements",
    "Pathfinding Queries": "Specialized in exploring connections between nodes, these queries are used to find the shortest path, identify all paths up to a certain length, or explore possible routes within a network. They are essential for applications in network analysis, routing, logistics, and social network exploration. Always limit the number of results if more than one row is expected from the questions by saying 'first 3' or 'top 5' elements",
    "Complex Aggregation Queries": "The most sophisticated category, these queries involve multiple aggregation functions and often group results over complex subgraphs. They calculate metrics like average number of reports per manager or total sales volume through a network, supporting strategic decision making and advanced reporting. Always limit the number of results if more than one row is expected from the questions by saying 'first 3' or 'top 5' elements",
    "Verbose query": "These queries are characterized by their explicit and detailed specifications about the data retrieval process and the exact information needed. They involve elaborate instructions for navigating through complex data structures, specifying precise criteria for inclusion, exclusion, and sorting of data points. Verbose queries typically require the breakdown of each step in the querying process, from the initial identification of relevant data nodes and relationships to the intricate filtering and sorting mechanisms that must be applied. Always limit the number of results if more than one row is expected from the questions by saying 'first 3' or 'top 5' elements",
}

# %% [markdown]
# ### Connect to Neo4j

# %%
graph = Neo4jGraph(url=neo4j_url,username=neo4j_user,password=neo4j_password,sanitize=True,enhanced_schema=True)
schema = graph.schema
all_questions = []
for type in query_types:
  print(type)
  instructions = f"{type}: {query_types[type]}"
  values = graph.query(
            """
            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2
            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}
            RETURN p
            """
            )
  questions = chain.invoke( {"input": schema, "instructions": instructions, "values": values})
  all_questions.extend([{"question": el, "type": type} for el in questions.questions])
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (n) { ... }} {position: line: 3, column: 13, offset: 69} for query: '\n            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2\n            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}\n            RETURN p\n            '
# Simple Retrieval Queries
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (n) { ... }} {position: line: 3, column: 13, offset: 69} for query: '\n            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2\n            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}\n            RETURN p\n            '
# Complex Retrieval Queries
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (n) { ... }} {position: line: 3, column: 13, offset: 69} for query: '\n            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2\n            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}\n            RETURN p\n            '
# Simple Aggregation Queries
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (n) { ... }} {position: line: 3, column: 13, offset: 69} for query: '\n            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2\n            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}\n            RETURN p\n            '
# Pathfinding Queries
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (n) { ... }} {position: line: 3, column: 13, offset: 69} for query: '\n            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2\n            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}\n            RETURN p\n            '
# Complex Aggregation Queries
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (n) { ... }} {position: line: 3, column: 13, offset: 69} for query: '\n            MATCH (n) WHERE rand() > 0.6 WITH n LIMIT 2\n            CALL { WITH n MATCH p=(n)-[*3..3]-() RETURN p LIMIT 1}\n            RETURN p\n            '
# Verbose query

# %%
import random

random_elements = random.sample(all_questions, 10)

print(random_elements)
# Out:
# [{'question': 'What is the average overall rating of players who play as defenders?', 'type': 'Verbose query'}, {'question': 'What is the name of the club a player named Ronaldinho plays for?', 'type': 'Pathfinding Queries'}, {'question': 'Which players have a release clause above 10,000,000?', 'type': 'Complex Retrieval Queries'}, {'question': 'What is the name of the club with the highest number of players with a wage above 20,000?', 'type': 'Simple Retrieval Queries'}, {'question': 'What is the average overall rating of players who play as goalkeepers?', 'type': 'Verbose query'}, {'question': 'Which players have a performance best overall above 80?', 'type': 'Complex Retrieval Queries'}, {'question': 'Which players have a performance best overall below 70?', 'type': 'Complex Retrieval Queries'}, {'question': 'What is the wage of a player who has a potential of 83.0 and plays for a club named Querétaro and has an overall rating above 80 and plays as a CAM?', 'type': 'Pathfinding Queries'}, {'question': 'What are the names of all players who have a value above 500000?', 'type': 'Complex Aggregation Queries'}, {'question': 'Which players have a performance overall rating below 60?', 'type': 'Complex Retrieval Queries'}]

# %%
all_questions_df = pd.DataFrame.from_records(all_questions)
all_questions_df.to_csv('../processed_data/text2cypher_questions.csv', index = False)

# %%
class CypherQuery(BaseModel):
    cypherquery: str = Field(
        description="A correct Neo4J Cypher Query Language without any preambles. Make sure that it follows the schema"
    )


structured_llm_cypher_query = llm.with_structured_output(CypherQuery)

system_prompt_cypher_query = """Given an input question, convert it to a Cypher query. No pre-amble.
Additional instructions:
- Ensure that queries checking for non-null properties use `IS NOT NULL` in a straightforward manner.
- Don't use `size((n)--(m))` for counting relationships. Instead use the new `count{{(n)--(m))}}` syntax.
- Incorporate the new existential subqueries in examples where the query needs to check for the existence of a pattern.
  Example: MATCH (p:Person)-[r:IS_FRIENDS_WITH]->(friend:Person)
            WHERE exists{{ (p)-[:WORKS_FOR]->(:Company {{name: 'Neo4j'}})}}
            RETURN p, r, friend"""

default_prompt_cypher_query = ChatPromptTemplate.from_messages(
    [
        SystemMessagePromptTemplate.from_template(
            f"{system_prompt_cypher_query}"
        ),
        HumanMessagePromptTemplate.from_template(
            """Based on the Neo4j graph schema below, write a Cypher query that would answer the user's question: {schema}"
              Question: {question}
              Cypher query:"""),
    ]
)

chain_cypher_query = default_prompt_cypher_query | structured_llm_cypher_query

# %%
chain_cypher_query.invoke({"schema": schema, "question":"Whats the team that Vini Jr plays for?"}).cypherquery
# Out:
# "MATCH (p:Player)-[r:PLAYS_FOR]->(c:Club) WHERE p.name = 'Vini Jr' RETURN c.name"

# %%
import time

graph = Neo4jGraph(url=neo4j_url,username=neo4j_user,password=neo4j_password,sanitize=True,enhanced_schema=True)
schema = graph.schema

def get_cypher_query(question):
    cypher_query = chain_cypher_query.invoke({"schema": schema, "question": question}).cypherquery
    time.sleep(1)
    return cypher_query

def safe_get_cypher_query(question):
    retry_count = 3
    for attempt in range(retry_count):
        try:
            result = get_cypher_query(question)
            print(question, ':', result)
            return result
        except Exception as e:
            print(f"Error: {e}. Retrying ({attempt + 1}/{retry_count})...")
            time.sleep(random.uniform(1, 3))
    return None
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"

# %%
df['cypher'] = df['question'].apply(lambda q: safe_get_cypher_query(q))
# Out:
# What is the name of the player with the highest overall rating and the highest potential rating and the highest wage and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating? : MATCH (p:Player)
# WITH p, max(p.overall_rating) as max_overall, max(p.potential) as max_potential, max(p.wage) as max_wage, max(p.release_clause) as max_release_clause
# WHERE p.overall_rating = max_overall AND p.potential = max_potential AND p.wage = max_wage AND p.release_clause = max_release_clause
# RETURN p.name
# What is the name of the player with the highest overall rating and the highest potential rating and the highest wage and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value? : MATCH (p:Player) WITH p ORDER BY p.overall_rating DESC, p.potential DESC, p.wage DESC, p.release_clause DESC RETURN p.name AS name
# What is the name of the player with the highest overall rating and the highest potential rating and the highest wage and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating? : MATCH (p:Player) WHERE p.overall_rating > 80 AND p.potential > 80 AND p.wage > 0 AND p.release_clause > 0 RETURN p.name AS name, p.overall_rating AS overall_rating, p.potential AS potential, p.wage AS wage, p.release_clause AS release_clause ORDER BY p.overall_rating DESC, p.potential DESC, p.wage DESC, p.release_clause DESC LIMIT 1
# What is the name of the player with the highest overall rating and the highest potential rating and the highest wage and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating? : MATCH (p:Player) WHERE p.overall_rating > 80 AND p.potential > 80 AND p.wage > 0 AND p.release_clause > 0 RETURN p.name, p.overall_rating, p.potential, p.wage, p.release_clause ORDER BY p.overall_rating DESC, p.potential DESC, p.wage DESC, p.release_clause DESC LIMIT 1
# What is the name of the player with the highest overall rating and the highest potential rating and the highest wage and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating and the highest release clause value and the highest overall rating and the highest potential rating? : MATCH (p:Player) WHERE p.overall_rating > 80 AND p.potential > 0 AND p.wage > 0 AND p.release_clause > 0 RETURN p.name
# What is the total value of all players with an overall rating above 85? : MATCH (p:Player) WHERE p.overall_rating > 85 RETURN sum(p.value) AS total_value
# Which clubs have the most players with an overall rating above 85? : MATCH (c:Club)-[:PLAYS_FOR]->(p:Player) WHERE p.overall_rating > 85 RETURN c.name, count(p) AS count ORDER BY count DESC
# What is the average wage of all players with an overall rating above 85? : MATCH (p:Player) WHERE p.overall_rating > 85 RETURN avg(p.wage) AS average_wage
# Which players have a best overall rating above 85? : MATCH (p:Player) WHERE p.best_overall > 85 RETURN p
# Which clubs have the most players with a best overall rating above 85? : MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:HAS_PERFORMANCE]->(perf:Performance) WHERE perf.best_overall > 85 WITH c, COUNT(p) AS num_players RETURN c, num_players ORDER BY num_players DESC
# What is the average wage of all players with a best overall rating above 85? : MATCH (p:Player) WHERE p.best_overall > 85 MATCH (p)-[r:HAS_FINANCIALS]->(f:Financials) RETURN avg(f.wage) AS average_wage
# Which players have a value above 20M? : MATCH (p:Player) WHERE p.value > 20000000 RETURN p
# What is the total release clause of all players with a value above 20M? : MATCH (p:Player)-[r:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 20000000.0 RETURN sum(f.release_clause) AS total_release_clause
# Which clubs have the most players with a value above 20M? : MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 20000000 GROUP BY c ORDER BY size(collect(p)) DESC RETURN c
# What is the average wage of all players with a value above 20M? : MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 20000000.0 RETURN avg(f.wage)
# Which players have an overall rating above 80 and a value above 10M? : MATCH (p:Player) WHERE p.overall_rating > 80 AND p.value > 10E6 RETURN p.name, p.overall_rating, p.value
# What is the total value of all players with an overall rating above 80 and a value above 10M? : MATCH (player:Player)-[:HAS_FINANCIALS]->(financials:Financials)-[:HAS_PERFORMANCE]->(performance:Performance) WHERE player.overall_rating > 80 AND financials.value > 10000000 RETURN sum(financials.value) AS total_value
# Which clubs have the most players with an overall rating above 80 and a value above 10M? : MATCH (c:Club)-[:PLAYS_FOR]->(p:Player) WHERE p.overall_rating > 80 AND p.value > 10000000 MATCH (c) WITH c, COLLECT(DISTINCT p) AS players ORDER BY SIZE(players) DESC RETURN c, players LIMIT 10
# What is the average wage of all players with an overall rating above 80 and a value above 10M? : MATCH (p:Player) WHERE p.overall_rating > 80 AND p.value > 10000000.0 RETURN avg(p.wage) AS average_wage
# Which players have a best overall rating above 80 and a value above 10M? : MATCH (p:Player) WHERE p.best_overall > 80 AND p.value > 10000000 RETURN p
# What is the total value of all players with a best overall rating above 80 and a value above 10M? : MATCH (p:Player)-[:HAS_PERFORMANCE]->(perf:Performance)-[:HAS_FINANCIALS]->(fin:Financials) WHERE perf.best_overall > 80 AND fin.value > 10000000 RETURN sum(fin.value) as total_value
# Which clubs have the most players with a best overall rating above 80 and a value above 10M? : MATCH (c:Club)-[:PLAYS_FOR]->(p:Player) WHERE p.best_overall > 80 AND p.value > 10000000 RETURN c.name AS club, COUNT(DISTINCT p) AS count ORDER BY count DESC LIMIT 10
# What is the average wage of all players with a best overall rating above 80 and a value above 10M? : MATCH (p:Player) WHERE p.best_overall > 80 AND p.value > 10000000.0 RETURN avg(p.wage) AS average_wage
# Which players have a value above 50M and a release clause above 10M? : MATCH (p:Player) WHERE p.value > 5000000 AND p.release_clause > 10000000 RETURN p
# What is the total value of all players with a value above 50M and a release clause above 10M? : MATCH (p:Player)-[r:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 50000000 AND f.release_clause > 10000000 RETURN sum(f.value) AS total_value
# Which clubs have the most players with a value above 50M and a release clause above 10M? : MATCH (c:Club)-[:PLAYS_FOR]-(p:Player) WHERE p.value > 5000000 AND p.release_clause > 10000000 RETURN c.name AS club_name
# What is the average wage of all players with a value above 50M and a release clause above 10M? : MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 50000000 AND f.release_clause > 10000000 RETURN avg(f.wage)
# Which players have an overall rating above 85 and a value above 10M? : MATCH (p:Player) WHERE p.overall_rating > 85 AND p.value > 10000000 RETURN p
# What is the total value of all players with an overall rating above 85 and a value above 10M? : MATCH (p:Player)-[:PLAYS_FOR]->(c:Club) WHERE p.overall_rating > 85 AND p.value > 10000000 RETURN sum(p.value) AS total_value
# Which clubs have the most players with an overall rating above 85 and a value above 10M? : MATCH (c:Club)-->(p:Player) WHERE p.overall_rating > 85 AND p.value > 10000000 RETURN c.name AS club_name, COUNT(DISTINCT p) AS num_players ORDER BY num_players DESC
# What is the average wage of all players with an overall rating above 85 and a value above 10M? : MATCH (p:Player) WHERE p.overall_rating > 85 AND p.value > 10000000 RETURN p.wage AS wage SUM(wage) AS total_wage / size(collect(p)) AS avg_wage
# Which players have a best overall rating above 85 and a value above 10M? : MATCH (p:Player) WHERE p.best_overall > 85 AND p.value > 1e7 RETURN p
# What is the total value of all players with a best overall rating above 85 and a value above 10M? : MATCH (p:Player) WHERE p.best_overall > 85 AND p.value > 10000000 RETURN sum(p.value) AS total_value
# Which clubs have the most players with a best overall rating above 85 and a value above 10M? : MATCH (club:Club)-[:PLAYS_FOR]-(player:Player)-[:HAS_PERFORMANCE]->(performance:Performance) WHERE performance.best_overall > 85 AND player.HAS_FINANCIALS->(:Financials {value: {gt: 10000000}}) RETURN DISTINCT club
# What is the average wage of all players with a best overall rating above 85 and a value above 10M? : MATCH (p:Player)-[:PLAYS_FOR]->(c:Club) WHERE p.best_overall > 85 AND p.value > 10000000 MATCH (p)-[:HAS_FINANCIALS]->(f:Financials) RETURN avg(f.wage) AS average_wage
# Which players have a value above 20M and a release clause above 10M? : MATCH (p:Player) WHERE p.value > 20000000 AND p.release_clause > 10000000 RETURN p
# What is the total value of all players with a value above 20M and a release clause above 10M? : MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 20000000 AND f.release_clause > 10000000 RETURN sum(p.value) AS total_value
# Which clubs have the most players with a value above 20M and a release clause above 10M? : MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 20000000 AND f.release_clause > 10000000 RETURN c.name AS club, COUNT(DISTINCT p) AS num_players
# Error: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n    "tool_calls": [\n        {\n            "id": "pending",\n            "type": "function",\n            "function": {\n                "name": "CypherQuery"\n            },\n            "parameters": {\n                "properties": {\n                    "cypherquery": "MATCH (p:Player) WHERE p.value > 20000000 AND p.release_clause > 10000000 RETURN avg(p.wage)"\n                }\n            }\n        }\n    ]\n}\n</tool-use>'}}. Retrying (1/3)...
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[13], line 15, in safe_get_cypher_query(question)
#      14 try:
# ---> 15     result = get_cypher_query(question)
#      16     print(question, ':', result)
#
# Cell In[13], line 7, in get_cypher_query(question)
#       6 def get_cypher_query(question):
# ----> 7     cypher_query = chain_cypher_query.invoke({"schema": schema, "question": question}).cypherquery
#       8     time.sleep(1)
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\runnables\base.py:5354, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5348 def invoke(
#    5349     self,
#    5350     input: Input,
#    5351     config: Optional[RunnableConfig] = None,
#    5352     **kwargs: Optional[Any],
#    5353 ) -> Output:
# -> 5354     return self.bound.invoke(
#    5355         input,
#    5356         self._merge_configs(config),
#    5357         **{**self.kwargs, **kwargs},
#    5358     )
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     283 config = ensure_config(config)
#     284 return cast(
#     285     ChatGeneration,
# --> 286     self.generate_prompt(
#     287         [self._convert_input(input)],
#     288         stop=stop,
#     289         callbacks=config.get("callbacks"),
#     290         tags=config.get("tags"),
#     291         metadata=config.get("metadata"),
#     292         run_name=config.get("run_name"),
#     293         run_id=config.pop("run_id", None),
#     294         **kwargs,
#     295     ).generations[0][0],
#     296 ).message
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     785 prompt_messages = [p.to_messages() for p in prompts]
# --> 786 return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     631 try:
#     632     results.append(
# --> 633         self._generate_with_cache(
#     634             m,
#     635             stop=stop,
#     636             run_manager=run_managers[i] if run_managers else None,
#     637             **kwargs,
#     638         )
#     639     )
#     640 except BaseException as e:
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     850 if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851     result = self._generate(
#     852         messages, stop=stop, run_manager=run_manager, **kwargs
#     853     )
#     854 else:
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\langchain_groq\chat_models.py:474, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     470 params = {
#     471     **params,
#     472     **kwargs,
#     473 }
# --> 474 response = self.client.create(messages=message_dicts, **params)
#     475 return self._create_chat_result(response)
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\groq\resources\chat\completions.py:298, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     188 """
#     189 Creates a model response for the given chat conversation.
#     190
#    (...)
#     296   timeout: Override the client-level default timeout for this request, in seconds
#     297 """
# --> 298 return self._post(
#     299     "/openai/v1/chat/completions",
#     300     body=maybe_transform(
#     301         {
#     302             "messages": messages,
#     303             "model": model,
#     304             "frequency_penalty": frequency_penalty,
#     305             "function_call": function_call,
#     306             "functions": functions,
#     307             "logit_bias": logit_bias,
#     308             "logprobs": logprobs,
#     309             "max_tokens": max_tokens,
#     310             "n": n,
#     311             "parallel_tool_calls": parallel_tool_calls,
#     312             "presence_penalty": presence_penalty,
#     313             "response_format": response_format,
#     314             "seed": seed,
#     315             "stop": stop,
#     316             "stream": stream,
#     317             "temperature": temperature,
#     318             "tool_choice": tool_choice,
#     319             "tools": tools,
#     320             "top_logprobs": top_logprobs,
#     321             "top_p": top_p,
#     322             "user": user,
#     323         },
#     324         completion_create_params.CompletionCreateParams,
#     325     ),
#     326     options=make_request_options(
#     327         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     328     ),
#     329     cast_to=ChatCompletion,
#     330     stream=stream or False,
#     331     stream_cls=Stream[ChatCompletionChunk],
#     332 )
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\groq\_base_client.py:1263, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1260 opts = FinalRequestOptions.construct(
#    1261     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1262 )
# -> 1263 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\groq\_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\groq\_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\groq\_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\groq\_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n    "tool_calls": [\n        {\n            "id": "pending",\n            "type": "function",\n            "function": {\n                "name": "CypherQuery"\n            },\n            "parameters": {\n                "properties": {\n                    "cypherquery": "MATCH (p:Player) WHERE p.value > 20000000 AND p.release_clause > 10000000 RETURN avg(p.wage)"\n                }\n            }\n        }\n    ]\n}\n</tool-use>'}}
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['cypher'] = df['question'].apply(lambda q: safe_get_cypher_query(q))
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\COMP\ajai\GraphRAG\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[14], line 1, in <lambda>(q)
# ----> 1 df['cypher'] = df['question'].apply(lambda q: safe_get_cypher_query(q))
#
# Cell In[13], line 20, in safe_get_cypher_query(question)
#      18     except Exception as e:
#      19         print(f"Error: {e}. Retrying ({attempt + 1}/{retry_count})...")
# ---> 20         time.sleep(random.uniform(1, 3))
#      21 return None
#
# NameError: name 'random' is not defined

# %%
# df.to_excel('../processed_data/text2cypher_questions_with_cypher.xlsx',index=False)

# %%
df=pd.read_excel(r'../processed_data/text2cypher_questions_with_cypher.xlsx')
df
# Out:
#                                               question  \
# 0    Which clubs have the most players with an over...
# 1    Which clubs have the most players with a value...
# 2    Which clubs have the most players with a best ...
# 3    What is the average wage of all players with a...
# 4    Which players have a best overall rating above...
# ..                                                 ...
# 213  What is the average wage of players who are pl...
# 214  What is the average overall rating of players ...
# 215  What is the average wage of players who are pl...
# 216  Which players have a wage above 5000 and are n...
# 217  What is the total value of all players with an...
#
#                            type  \
# 0    Simple Aggregation Queries
# 1    Simple Aggregation Queries
# 2    Simple Aggregation Queries
# 3    Simple Aggregation Queries
# 4    Simple Aggregation Queries
# ..                          ...
# 213   Complex Retrieval Queries
# 214   Complex Retrieval Queries
# 215   Complex Retrieval Queries
# 216   Complex Retrieval Queries
# 217  Simple Aggregation Queries
#
#                                                 cypher
# 0    MATCH (p:Player)-[:PLAYS_FOR]->(c:Club) WHERE ...
# 1    MATCH (p:Player)-[:PLAYS_FOR]->(c:Club), (p)-[...
# 2    MATCH (p:Player)-[:PLAYS_FOR]->(c:Club), (p)-[...
# 3    MATCH (p:Player) WHERE p.best_overall > 85 MAT...
# 4    MATCH (p:Player) WHERE p.best_overall > 85 RET...
# ..                                                 ...
# 213  MATCH (p:Player)-[r:PLAYS_AS]->(pos:Position {...
# 214  MATCH (p:Player)-[r:PLAYS_AS]->(pos:Position)-...
# 215  MATCH (p:Player)-[r:PLAYS_AS]->(pos:Position)<...
# 216  MATCH (p:Player)-[r:PLAYS_FOR]->(c:Club) WHERE...
# 217  MATCH (player:Player)-[:HAS_FINANCIALS]->(fina...
#
# [218 rows x 3 columns]

# %% [markdown]
# ### Evaluate the generated Cypher query by running it against the database. Check if it has any syntax errors, times out, or returns a result.

# %%
graph = Neo4jGraph(url=neo4j_url, username=neo4j_user, password=neo4j_password, sanitize=True, enhanced_schema=True)

# Define the function to execute the query and handle errors
def execute_query(row):
    try:
        # Execute the Cypher query from the 'cypher' column
        data = graph.query(row["cypher"])
        
        # Check if the query returned data
        if data:
            return pd.Series([True, False, False])  # returns_results, syntax_error, timeout_error
        else:
            return pd.Series([False, False, False])  # No results, no error, no timeout
    
    except ValueError as e:
        # Handle invalid Cypher query errors
        if "Generated Cypher Statement is not valid" in str(e):
            print(f"Syntax error in Cypher query: {e}")
            return pd.Series([False, True, False])  # False for results, True for syntax error, no timeout
        else:
            print(f"Other ValueError: {e}")
            return pd.Series([False, False, False])  # False for results, no error, no timeout
    
    except Exception as e:
        # Handle timeout errors
        if hasattr(e, 'code') and e.code == "Neo.ClientError.Transaction.TransactionTimedOutClientConfiguration":
            return pd.Series([False, False, True])  # False for results, no syntax error, True for timeout
        else:
            # Handle other exceptions
            print(f"Unexpected error: {e}")
            return pd.Series([False, False, False])  # False for results, no error, no timeout

# Apply the function to the 'cypher' column and unpack the returned Series into new columns
df[['query_result', 'syntax_error', 'timeout_error']] = df.apply(execute_query, axis=1)
df
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'nan': expected 'FOREACH', 'ALTER', 'ORDER BY', 'CALL', 'USING PERIODIC COMMIT', 'CREATE', 'LOAD CSV', 'START DATABASE', 'STOP DATABASE', 'DEALLOCATE', 'DELETE', 'DENY', 'DETACH', 'DROP', 'DRYRUN', 'FINISH', 'GRANT', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REALLOCATE', 'REMOVE', 'RENAME', 'RETURN', 'REVOKE', 'ENABLE SERVER', 'SET', 'SHOW', 'SKIP', 'TERMINATE', 'UNWIND', 'USE' or 'WITH' (line 1, column 1 (offset: 0))
# "nan"
#  ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: A pattern expression should only be used in order to test the existence of a pattern. It can no longer be used inside the function size(), an alternative is to replace size() with COUNT {}. (line 1, column 176 (offset: 175))
# "MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:PLAYS_AS]->(pos:Position)<-[:HAS_PERFORMANCE]-(perf:Performance) WHERE perf.overall_rating > 75 AND pos.name = 'Goalkeeper' AND size((c)-[:PLAYS_FOR]->(p)) > 2 RETURN c.name AS name"
#                                                                                                                                                                                 ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'max': expected an expression (line 1, column 46 (offset: 45))
# "MATCH (p:Player) WHERE p.potential = (SELECT max(p2.potential) FROM (p:Player)) AND p.overall_rating = (SELECT max(p2.overall_rating) FROM (p:Player)) RETURN p.name"
#                                               ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'GROUP': expected a graph pattern, 'FOREACH', ',', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'USING', 'WHERE', 'WITH' or <EOF> (line 1, column 115 (offset: 114))
# "MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financials) WHERE f.value > 10000000 MATCH (p)-[:PLAYS_AS]->(pos:Position) GROUP BY pos RETURN pos.name AS position, COUNT(p) AS count ORDER BY count DESC"
#                                                                                                                    ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'MAX': expected an expression (line 1, column 124 (offset: 123))
# "MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financials)-[:HAS_PERFORMANCE]->(perf:Performance) WHERE f.release_clause = (SELECT MAX(f2.release_clause) FROM (p:Player)-[:HAS_FINANCIALS]->(f2:Financials)) AND perf.overall_rating = (SELECT MAX(perf2.overall_rating) FROM (p:Player)-[:HAS_PERFORMANCE]->(perf2:Performance)) RETURN p.name"
#                                                                                                                             ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Variable `financials` not defined (line 1, column 96 (offset: 95))
# "MATCH (p:Player)-[:PLAYS_AS]->(:Position {name: 'Left winger'})-[:PLAYS_FOR]->(c:Club) WHERE p(financials.value) > 8500000 RETURN p"
#                                                                                                 ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '{': expected an identifier or '}' (line 1, column 46 (offset: 45))
# "MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {{ name: 'Forward' }}) WHERE p.release_clause > 2000000 RETURN p"
#                                               ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '{': expected an identifier or '}' (line 1, column 46 (offset: 45))
# "MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {{name: 'CAM'}})-[:HAS_PERFORMANCE]->(perf:Performance) RETURN avg(p.wage) AS average_wage"
#                                               ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'GROUP': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 69 (offset: 68))
# "MATCH (p:Player)-[:PLAYS_AS]->(pos:Position) WHERE p.potential > 90 GROUP BY pos.name ORDER BY COUNT(p) DESC LIMIT 10 RETURN pos.name AS position, COUNT(p) AS count"
#                                                                      ^}
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: HAS_FOOT)} {position: line: 1, column: 48, offset: 47} for query: "MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[:HAS_FOOT]->(foot:Foot {type:'Right'})-[:HAS_FINANCIALS]->(fin:Financials) WHERE p.fin.value > 8500000 RETURN p"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: fin)} {position: line: 1, column: 130, offset: 129} for query: "MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[:HAS_FOOT]->(foot:Foot {type:'Right'})-[:HAS_FINANCIALS]->(fin:Financials) WHERE p.fin.value > 8500000 RETURN p"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: performance)} {position: line: 1, column: 138, offset: 137} for query: "MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[:USES_FOOT]->(foot:Foot) WHERE p.overall_rating > 80 AND pos.name = 'Right defender' AND p.performance.overall_rating > 85 RETURN p"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: HAS_AGE_GROUP)} {position: line: 1, column: 53, offset: 52} for query: "MATCH (p:Player)-[:PLAYS_AS]->(position:Position)-[:HAS_AGE_GROUP]->(agegroup:AgeGroup) WHERE p.potential > 90 AND agegroup.name = 'Veteran' RETURN p.name"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: age_group)} {position: line: 1, column: 164, offset: 163} for query: "MATCH (p:Player)-[:PLAYS_AS]->(position:Position)-[:HAS_ROLE]->(role:Role)-[:HAS_PERFORMANCE]->(performance:Performance) WHERE p.best_overall > 85 AND performance.age_group.name = 'Veteran' RETURN p.name"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: IS_IN_AGE_GROUP)} {position: line: 1, column: 90, offset: 89} for query: "MATCH (p:Player)-[:PLAYS_FOR]->() WHERE p.release_clause > 8300000 AND NOT exists{ (p)-[:IS_IN_AGE_GROUP]->(:AgeGroup {name: 'Young Adult'})} RETURN p"
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Query cannot conclude with MATCH (must be a RETURN clause, a FINISH clause, an update clause, a unit subquery call, or a procedure call with no YIELD). (line 1, column 1 (offset: 0))
# "MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)"
#  ^}
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Query cannot conclude with MATCH (must be a RETURN clause, a FINISH clause, an update clause, a unit subquery call, or a procedure call with no YIELD). (line 1, column 1 (offset: 0))
# "MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)"
#  ^}
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: AGE_GROUP)} {position: line: 1, column: 89, offset: 88} for query: "MATCH (p:Player)-[:PLAYS_FOR]->(c:Club) WHERE p.release_clause > 12300000 AND NOT (p)-[:AGE_GROUP]->(:AgeGroup {name: 'Young Adult'}) RETURN p"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: age_group)} {position: line: 1, column: 177, offset: 176} for query: "MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)-[:PLAYS_AS]->(pos:Position)-[:HAS_ROLE]->(role:Role)-[:HAS_PERFORMANCE]->(perf:Performance)-[:HAS_FINANCIALS]->(fin:Financials) WHERE p.age_group = 'Teenager' RETURN avg(fin.wage) AS average_wage"
# Unexpected error: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '{': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 189 (offset: 188))
# "MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)-[:PLAYS_AS]->(pos:Position)-[:HAS_ROLE]->(role:Role)-[:HAS_PERFORMANCE]->(perf:Performance)-[:HAS_FINANCIALS]->(fin:Financials) WHERE p.age:AgeGroup{name:'Prime'} AND fin.value > 1.5E8 RETURN p"
#                                                                                                                                                                                              ^}
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: PLAYS_IN)} {position: line: 1, column: 20, offset: 19} for query: "MATCH (p:Player)-[:PLAYS_IN {age_group: 'Veteran'}]->() WITH avg(p.overall_rating) as average_rating RETURN average_rating"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: age_group)} {position: line: 1, column: 30, offset: 29} for query: "MATCH (p:Player)-[:PLAYS_IN {age_group: 'Veteran'}]->() WITH avg(p.overall_rating) as average_rating RETURN average_rating"
#                                               question  \
# 0    Which clubs have the most players with an over...
# 1    Which clubs have the most players with a value...
# 2    Which clubs have the most players with a best ...
# 3    What is the average wage of all players with a...
# 4    Which players have a best overall rating above...
# ..                                                 ...
# 213  What is the average wage of players who are pl...
# 214  What is the average overall rating of players ...
# 215  What is the average wage of players who are pl...
# 216  Which players have a wage above 5000 and are n...
# 217  What is the total value of all players with an...
#
#                            type  \
# 0    Simple Aggregation Queries
# 1    Simple Aggregation Queries
# 2    Simple Aggregation Queries
# 3    Simple Aggregation Queries
# 4    Simple Aggregation Queries
# ..                          ...
# 213   Complex Retrieval Queries
# 214   Complex Retrieval Queries
# 215   Complex Retrieval Queries
# 216   Complex Retrieval Queries
# 217  Simple Aggregation Queries
#
#                                                 cypher  query_result  \
# 0    MATCH (p:Player)-[:PLAYS_FOR]->(c:Club) WHERE ...          True
# 1    MATCH (p:Player)-[:PLAYS_FOR]->(c:Club), (p)-[...          True
# 2    MATCH (p:Player)-[:PLAYS_FOR]->(c:Club), (p)-[...          True
# 3    MATCH (p:Player) WHERE p.best_overall > 85 MAT...          True
# 4    MATCH (p:Player) WHERE p.best_overall > 85 RET...          True
# ..                                                 ...           ...
# 213  MATCH (p:Player)-[r:PLAYS_AS]->(pos:Position {...          True
# 214  MATCH (p:Player)-[r:PLAYS_AS]->(pos:Position)-...          True
# 215  MATCH (p:Player)-[r:PLAYS_AS]->(pos:Position)<...          True
# 216  MATCH (p:Player)-[r:PLAYS_FOR]->(c:Club) WHERE...          True
# 217  MATCH (player:Player)-[:HAS_FINANCIALS]->(fina...          True
#
#      syntax_error  timeout_error
# 0           False          False
# 1           False          False
# 2           False          False
# 3           False          False
# 4           False          False
# ..            ...            ...
# 213         False          False
# 214         False          False
# 215         False          False
# 216         False          False
# 217         False          False
#
# [218 rows x 6 columns]

# %%
df[df['query_result']==True]['type'].value_counts()
# Out:
# type
# Simple Aggregation Queries    106
# Complex Retrieval Queries      35
# Simple Retrieval Queries       23
# Name: count, dtype: int64

# %%
df[df['query_result']==False].reset_index(drop=True)
# Out:
#                                              question  \
# 0   Which clubs have the most players with a finan...
# 1   Which clubs have more than 3 players with a be...
# 2   Which clubs have more than 2 players with a ov...
# 3   Which clubs have more than 2 players with a ov...
# 4   Which clubs have more than 2 players with a ov...
# 5   What are the names of all players who have a o...
# 6   What is the name of the player with the highes...
# 7   Which positions have the most players with a v...
# 8   What is the name of the player with the highes...
# 9   Which players have a financial value above 3.5...
# 10  Which players have a financial value above 850...
# 11  Which players have a financial value above 1.8...
# 12  Which players have a financial value above 850...
# 13  Which players have a wage above 250000 and pla...
# 14  Which players have a release clause above 2000...
# 15  What is the average wage of all players who ha...
# 16  Which players have a release clause value abov...
# 17  Which players have a financial value above 3.5...
# 18  Which players have a financial value above 850...
# 19  Which players have a value above 5000000 and p...
# 20  Which players have a release clause above 1500...
# 21  Which players have a potential rating above 90...
# 22  Which players have a release clause above 3000...
# 23  Which players have a performance rating above ...
# 24  Which positions have the most players with a p...
# 25  Which players have a release clause above 2500...
# 26  Which players have a financial value above 850...
# 27  Which players have a performance rating above ...
# 28  Which players have a potential rating above 90...
# 29  Which players have a performance rating above ...
# 30  What are the names of all players who play as ...
# 31  Which players have a potential rating above 90...
# 32  Which players have a performance rating above ...
# 33  Which players have a performance rating above ...
# 34  Which positions have the most players with a p...
# 35  What are the names of all players who play as ...
# 36  Which players have a release clause value abov...
# 37  Which players have a performance rating above ...
# 38  What are the names of all players who have a p...
# 39  What are the names of all players who have a b...
# 40  What are the names of all players who play as ...
# 41  Which players have a wage above 300000 and pla...
# 42  What are the names of all players who have pla...
# 43  What are the names of all players who have pla...
# 44  What are the names of all players who have pla...
# 45  What are the names of all players who have a o...
# 46  Which players have a financial value above 1.8...
# 47  Which players have an overall rating above 80 ...
# 48  Which players have a financial value above 1.5...
# 49  What is the name of the player with the highes...
# 50  What are the names of all players who have pla...
# 51  Which players have a performance rating above ...
# 52  What are the names of all players who play as ...
# 53  Which players have a value above 4000000 and p...
#
#                           type  \
# 0   Simple Aggregation Queries
# 1     Simple Retrieval Queries
# 2     Simple Retrieval Queries
# 3     Simple Retrieval Queries
# 4     Simple Retrieval Queries
# 5     Simple Retrieval Queries
# 6    Complex Retrieval Queries
# 7   Simple Aggregation Queries
# 8    Complex Retrieval Queries
# 9    Complex Retrieval Queries
# 10   Complex Retrieval Queries
# 11   Complex Retrieval Queries
# 12   Complex Retrieval Queries
# 13    Simple Retrieval Queries
# 14    Simple Retrieval Queries
# 15    Simple Retrieval Queries
# 16   Complex Retrieval Queries
# 17   Complex Retrieval Queries
# 18   Complex Retrieval Queries
# 19    Simple Retrieval Queries
# 20    Simple Retrieval Queries
# 21   Complex Retrieval Queries
# 22    Simple Retrieval Queries
# 23   Complex Retrieval Queries
# 24  Simple Aggregation Queries
# 25    Simple Retrieval Queries
# 26   Complex Retrieval Queries
# 27   Complex Retrieval Queries
# 28   Complex Retrieval Queries
# 29   Complex Retrieval Queries
# 30    Simple Retrieval Queries
# 31   Complex Retrieval Queries
# 32   Complex Retrieval Queries
# 33   Complex Retrieval Queries
# 34  Simple Aggregation Queries
# 35    Simple Retrieval Queries
# 36   Complex Retrieval Queries
# 37   Complex Retrieval Queries
# 38    Simple Retrieval Queries
# 39    Simple Retrieval Queries
# 40    Simple Retrieval Queries
# 41    Simple Retrieval Queries
# 42    Simple Retrieval Queries
# 43    Simple Retrieval Queries
# 44    Simple Retrieval Queries
# 45    Simple Retrieval Queries
# 46   Complex Retrieval Queries
# 47   Complex Retrieval Queries
# 48   Complex Retrieval Queries
# 49   Complex Retrieval Queries
# 50    Simple Retrieval Queries
# 51   Complex Retrieval Queries
# 52    Simple Retrieval Queries
# 53    Simple Retrieval Queries
#
#                                                cypher  query_result  \
# 0   MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:HAS_...         False
# 1                                                 NaN         False
# 2   MATCH (c:Club)<-[:PLAYS_FOR]-(p:Player)-[:HAS_...         False
# 3   MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:PLAY...         False
# 4   MATCH (c:Club)-[:PLAYS_FOR]->(p:Player)-[:PLAY...         False
# 5   MATCH (p:Player)-[:HAS_ROLE]->(ageGroup:AgeGro...         False
# 6   MATCH (p:Player) WHERE p.potential = (SELECT m...         False
# 7   MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financi...         False
# 8   MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financi...         False
# 9   MATCH (p:Player)-[:HAS_FINANCIALS]->(f:Financi...         False
# 10  MATCH (p:Player)-[:PLAYS_AS]->(:Position {name...         False
# 11  MATCH (p:Player)-[:PLAYS_AS]->(:Position {name...         False
# 12  MATCH (p:Player)-[:PLAYS_AS]->(:Position {name...         False
# 13  MATCH (p:Player)-[:PLAYS_AS]->(:Position {name...         False
# 14  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {{...         False
# 15  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {{...         False
# 16  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 17  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 18  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 19  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 20  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 21  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 22  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 23  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position {n...         False
# 24  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position) W...         False
# 25  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position) W...         False
# 26  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 27  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 28  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 29  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 30  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 31  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 32  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 33  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)-[...         False
# 34  MATCH (p:Player)-[:PLAYS_AS]->(pos:Position)<-...         False
# 35  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 36  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 37  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 38  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 39  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 40  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 41  MATCH (p:Player)-[:PLAYS_AS]->(position:Positi...         False
# 42  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club {name: ...         False
# 43  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club {name: ...         False
# 44  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club {name: ...         False
# 45            MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)         False
# 46            MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)         False
# 47  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club) WHERE ...         False
# 48  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)-[:PLAY...         False
# 49  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)-[:USES...         False
# 50  MATCH (p:Player)-[:PLAYS_FOR]->(c:Club)<-[:PLA...         False
# 51  MATCH (p:Player)-[:USES_FOOT]->(f:Foot {type: ...         False
# 52  MATCH (p:Player)-[:USES_FOOT]->(f:Foot {type: ...         False
# 53  MATCH (p:Player)-[:USES_FOOT]->(f:Foot {type: ...         False
#
#     syntax_error  timeout_error
# 0          False          False
# 1          False          False
# 2          False          False
# 3          False          False
# 4          False          False
# 5          False          False
# 6          False          False
# 7          False          False
# 8          False          False
# 9          False          False
# 10         False          False
# 11         False          False
# 12         False          False
# 13         False          False
# 14         False          False
# 15         False          False
# 16         False          False
# 17         False          False
# 18         False          False
# 19         False          False
# 20         False          False
# 21         False          False
# 22         False          False
# 23         False          False
# 24         False          False
# 25         False          False
# 26         False          False
# 27         False          False
# 28         False          False
# 29         False          False
# 30         False          False
# 31         False          False
# 32         False          False
# 33         False          False
# 34         False          False
# 35         False          False
# 36         False          False
# 37         False          False
# 38         False          False
# 39         False          False
# 40         False          False
# 41         False          False
# 42         False          False
# 43         False          False
# 44         False          False
# 45         False          False
# 46         False          False
# 47         False          False
# 48         False          False
# 49         False          False
# 50         False          False
# 51         False          False
# 52         False          False
# 53         False          False

# %%
df.to_excel('text2cypher_questions_with_cypher_validated.xlsx',index=False)

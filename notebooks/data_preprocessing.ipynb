# %% [markdown]
# ## Data Loading

# %%
import pandas as pd
data=pd.read_csv(r'../data/Football_players_data.csv')
data.head(3)
# Out:
#                    name  Age Overall rating Potential  \
# 0  15 Ronaldinho CAM ST   34             78        78
# 1  O. Hutchinson RM CAM   19             65        81
# 2            Brahim CAM   23             82        86
#
#              Team & Contract      ID   foot  Best overall Best position  \
# 0     Querétaro\n2014 ~ 2016   28130  Right            77           CAM
# 1  Ipswich Town\n2022 ~ 2025  260145   Left            67           CAM
# 2   Real Madrid\n2019 ~ 2027  231410  Right            84           CAM
#
#     Value  ... GK Positioning GK Reflexes  Total stats Base stats  \
# 0   €4.1M  ...              6          14         1875        377
# 1   €1.8M  ...              5           8         1651        351
# 2  €43.5M  ...             10           6         1897        409
#
#   International reputation Pace / Diving Shooting / Handling  \
# 0                        3            49                  72
# 1                        1            72                  54
# 2                        1            85                  74
#
#   Passing / Kicking  Dribbling / Reflexes Defending / Pace
# 0                83                    84               28
# 1                61                    70               44
# 2                78                    85               31
#
# [3 rows x 61 columns]

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# #### Remove duplicated row

# %%
print("No of duplicated rows: ",data.duplicated().sum())
data=data.drop_duplicates()
print("No of duplicated rows after droping dupliactes: ",data.duplicated().sum())
# Out:
# No of duplicated rows:  371
# No of duplicated rows after droping dupliactes:  0

# %% [markdown]
# #### Removing Positions and number from name column

# %%
data['name']=data['name'].replace(data['Best position'].unique(),'',regex=True) #Replace Positions in name column with empty string
data['name']=data['name'].str.replace(r'\d+','',regex=True) #replace position numbers in name column with empty string
data['name']=data['name'].str.strip() #remove leading and trailing spaces
data.head(3)
# Out:
#             name  Age Overall rating Potential            Team & Contract  \
# 0     Ronaldinho   34             78        78     Querétaro\n2014 ~ 2016
# 1  O. Hutchinson   19             65        81  Ipswich Town\n2022 ~ 2025
# 2         Brahim   23             82        86   Real Madrid\n2019 ~ 2027
#
#        ID   foot  Best overall Best position   Value  ... GK Positioning  \
# 0   28130  Right            77           CAM   €4.1M  ...              6
# 1  260145   Left            67           CAM   €1.8M  ...              5
# 2  231410  Right            84           CAM  €43.5M  ...             10
#
#   GK Reflexes  Total stats Base stats International reputation Pace / Diving  \
# 0          14         1875        377                        3            49
# 1           8         1651        351                        1            72
# 2           6         1897        409                        1            85
#
#   Shooting / Handling Passing / Kicking  Dribbling / Reflexes Defending / Pace
# 0                  72                83                    84               28
# 1                  54                61                    70               44
# 2                  74                78                    85               31
#
# [3 rows x 61 columns]

# %% [markdown]
# #### Adding and Subtracting the additional ratings in Overall rating and Potential column

# %%
def evaluate_expression(value):
    if "+" in value:
        parts=value.split("+")
        return int(parts[0])+int(parts[1])
    elif '-' in value:
        parts=value.split("-")
        return int(parts[0])-int(parts[1])
    else:
        return int(value)
    
data['Overall rating']=data['Overall rating'].apply(evaluate_expression)
data['Potential']=data['Potential'].apply(evaluate_expression)
data.sample(3)
# Out:
#                         name  Age  Overall rating  Potential  \
# 2968  A. Motaraghebjafarpour   20              59         72
# 2941               F. Watson   20              69         80
# 407                P. Kalulu   23              78         85
#
#           Team & Contract      ID   foot  Best overall Best position  Value  \
# 2968  Kalmar\n2023 ~ 2025  275004  Right            60           RWB  €525K
# 2941   Lanús\n2023 ~ 2027  272911  Right            71           CAM  €3.1M
# 407    Milan\n2020 ~ 2027  255654  Right            80            CB   €26M
#
#       ... GK Positioning GK Reflexes  Total stats Base stats  \
# 2968  ...             14          13         1544        341
# 2941  ...             13           5         1734        377
# 407   ...              9          11         1960        421
#
#      International reputation Pace / Diving Shooting / Handling  \
# 2968                        1            75                  40
# 2941                        1            69                  62
# 407                         1            80                  50
#
#      Passing / Kicking  Dribbling / Reflexes Defending / Pace
# 2968                50                    61               51
# 2941                68                    67               55
# 407                 68                    69               79
#
# [3 rows x 61 columns]

# %% [markdown]
# #### Seperating Team and Contract column

# %%
data[['Team','Contract']]=data['Team & Contract'].str.split('\n',n=1,expand=True)
data=data.drop(columns=['Team & Contract','ID'])
data.sample(3)
# Out:
#             name  Age  Overall rating  Potential   foot  Best overall  \
# 1251     D. Ozoh   18              61         81  Right            63
# 590   C. Volpato   19              69         85   Left            71
# 2297  S. Soumano   22              68         75  Right            70
#
#      Best position  Value Wage Release clause  ...  Total stats Base stats  \
# 1251            CB  €850K  €2K          €2.5M  ...         1691        365
# 590            CAM  €3.6M  €5K          €8.4M  ...         1718        370
# 2297            ST  €2.5M  €9K             €0  ...         1556        337
#
#      International reputation Pace / Diving Shooting / Handling  \
# 1251                        1            67                  53
# 590                         1            67                  64
# 2297                        1            69                  69
#
#      Passing / Kicking  Dribbling / Reflexes Defending / Pace            Team  \
# 1251                55                    63               58  Crystal Palace
# 590                 67                    71               39        Sassuolo
# 2297                52                    69               25  Quevilly Rouen
#
#                   Contract
# 1251           2022 ~ 2024
# 590            2023 ~ 2025
# 2297  Jun 30, 2024 On loan
#
# [3 rows x 61 columns]

# %%
def parse_euro(value):
    if 'M' in value:
        return float(value.replace("€",'').replace('M',""))*1_000_000
    elif 'K' in value:
        return float(value.replace("€",'').replace('K',""))*1_000
    else:
        return float(value.replace("€",''))

# %% [markdown]
# #### parsing M and K to numbers

# %%
data[['Value', 'Wage', 'Release clause']]=data[['Value', 'Wage', 'Release clause']].map(parse_euro)
data.head(3)
# Out:
#             name  Age  Overall rating  Potential   foot  Best overall  \
# 0     Ronaldinho   34              78         78  Right            77
# 1  O. Hutchinson   19              65         81   Left            67
# 2         Brahim   23              82         86  Right            84
#
#   Best position       Value      Wage  Release clause  ...  Total stats  \
# 0           CAM   4100000.0   45000.0             0.0  ...         1875
# 1           CAM   1800000.0    3000.0       4500000.0  ...         1651
# 2           CAM  43500000.0  145000.0      92400000.0  ...         1897
#
#   Base stats International reputation Pace / Diving Shooting / Handling  \
# 0        377                        3            49                  72
# 1        351                        1            72                  54
# 2        409                        1            85                  74
#
#   Passing / Kicking  Dribbling / Reflexes Defending / Pace          Team  \
# 0                83                    84               28     Querétaro
# 1                61                    70               44  Ipswich Town
# 2                78                    85               31   Real Madrid
#
#       Contract
# 0  2014 ~ 2016
# 1  2022 ~ 2025
# 2  2019 ~ 2027
#
# [3 rows x 61 columns]

# %% [markdown]
# #### int conversion and arithmetic operation for stats columns

# %%
def evaluate_expression(value):
    try:
        if "+" in value:
            parts=value.split("+")
            return int(parts[0])+int(parts[1])
        elif '-' in value:
            parts=value.split("-")
            return int(parts[0])-int(parts[1])
        else:
            return int(value)
    except ValueError:
        return None

# %%
columns_to_do=['Total attacking',
       'Crossing', 'Finishing', 'Heading accuracy', 'Short passing', 'Volleys',
       'Total skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long passing',
       'Ball control', 'Total movement', 'Acceleration', 'Sprint speed',
       'Agility', 'Reactions', 'Balance', 'Total power', 'Shot power',
       'Jumping', 'Stamina', 'Strength', 'Long shots', 'Total mentality',
       'Aggression', 'Interceptions', 'Att. Position', 'Vision', 'Penalties',
       'Composure', 'Total defending', 'Defensive awareness',
       'Standing tackle', 'Sliding tackle', 'Total goalkeeping', 'GK Diving',
       'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
       'Total stats', 'Base stats', 'International reputation',
       'Pace / Diving', 'Shooting / Handling', 'Passing / Kicking',
       'Dribbling / Reflexes', 'Defending / Pace']

data[columns_to_do]=data[columns_to_do].astype(str).map(evaluate_expression)
data.sample(3)
# Out:
#              name  Age  Overall rating  Potential   foot  Best overall  \
# 283     E. Millot   20              75         83   Left            77
# 2843  Grafite  RF   31              80         84  Right            80
# 1943     A. Ounas   26              74         74   Left            74
#
#      Best position       Value     Wage  Release clause  ...  Total stats  \
# 283            CAM  12500000.0  17000.0      23800000.0  ...         1921
# 2843            ST         0.0      0.0             0.0  ...         1937
# 1943            RM   4600000.0  27000.0       8700000.0  ...         1909
#
#       Base stats  International reputation  Pace / Diving  \
# 283          405                         1             73
# 2843         411                         3             77
# 1943         405                         2             83
#
#       Shooting / Handling  Passing / Kicking  Dribbling / Reflexes  \
# 283                    67                 71                    79
# 2843                   81                 64                    75
# 1943                   66                 70                    79
#
#       Defending / Pace           Team     Contract
# 283                 61  VfB Stuttgart  2021 ~ 2028
# 2843                33  VfL Wolfsburg  2007 ~ 2012
# 1943                44     LOSC Lille  2022 ~ 2024
#
# [3 rows x 61 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2749 entries, 0 to 3111
# Data columns (total 61 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      2749 non-null   object
#  1   Age                       2749 non-null   int64
#  2   Overall rating            2749 non-null   int64
#  3   Potential                 2749 non-null   int64
#  4   foot                      2749 non-null   object
#  5   Best overall              2749 non-null   int64
#  6   Best position             2749 non-null   object
#  7   Value                     2749 non-null   float64
#  8   Wage                      2749 non-null   float64
#  9   Release clause            2749 non-null   float64
#  10  Total attacking           2749 non-null   int64
#  11  Crossing                  2749 non-null   int64
#  12  Finishing                 2748 non-null   float64
#  13  Heading accuracy          2748 non-null   float64
#  14  Short passing             2749 non-null   int64
#  15  Volleys                   2748 non-null   float64
#  16  Total skill               2749 non-null   int64
#  17  Dribbling                 2749 non-null   int64
#  18  Curve                     2749 non-null   int64
#  19  FK Accuracy               2747 non-null   float64
#  20  Long passing              2749 non-null   int64
#  21  Ball control              2749 non-null   int64
#  22  Total movement            2749 non-null   int64
#  23  Acceleration              2749 non-null   int64
#  24  Sprint speed              2749 non-null   int64
#  25  Agility                   2749 non-null   int64
#  26  Reactions                 2749 non-null   int64
#  27  Balance                   2749 non-null   int64
#  28  Total power               2749 non-null   int64
#  29  Shot power                2749 non-null   int64
#  30  Jumping                   2749 non-null   int64
#  31  Stamina                   2749 non-null   int64
#  32  Strength                  2749 non-null   int64
#  33  Long shots                2748 non-null   float64
#  34  Total mentality           2749 non-null   int64
#  35  Aggression                2749 non-null   int64
#  36  Interceptions             2749 non-null   int64
#  37  Att. Position             2749 non-null   int64
#  38  Vision                    2749 non-null   int64
#  39  Penalties                 2749 non-null   int64
#  40  Composure                 2749 non-null   int64
#  41  Total defending           2749 non-null   int64
#  42  Defensive awareness       2747 non-null   float64
#  43  Standing tackle           2749 non-null   int64
#  44  Sliding tackle            2746 non-null   float64
#  45  Total goalkeeping         2749 non-null   int64
#  46  GK Diving                 2749 non-null   int64
#  47  GK Handling               2749 non-null   int64
#  48  GK Kicking                2749 non-null   int64
#  49  GK Positioning            2749 non-null   int64
#  50  GK Reflexes               2749 non-null   int64
#  51  Total stats               2749 non-null   int64
#  52  Base stats                2749 non-null   int64
#  53  International reputation  2749 non-null   int64
#  54  Pace / Diving             2749 non-null   int64
#  55  Shooting / Handling       2749 non-null   int64
#  56  Passing / Kicking         2749 non-null   int64
#  57  Dribbling / Reflexes      2749 non-null   int64
#  58  Defending / Pace          2749 non-null   int64
#  59  Team                      2749 non-null   object
#  60  Contract                  2749 non-null   object
# dtypes: float64(10), int64(46), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Verify null values

# %%
data_NA=data.isna().sum().reset_index().head(50)
data_NA
# Out:
#                   index  0
# 0                  name  0
# 1                   Age  0
# 2        Overall rating  0
# 3             Potential  0
# 4                  foot  0
# 5          Best overall  0
# 6         Best position  0
# 7                 Value  0
# 8                  Wage  0
# 9        Release clause  0
# 10      Total attacking  0
# 11             Crossing  0
# 12            Finishing  1
# 13     Heading accuracy  1
# 14        Short passing  0
# 15              Volleys  1
# 16          Total skill  0
# 17            Dribbling  0
# 18                Curve  0
# 19          FK Accuracy  2
# 20         Long passing  0
# 21         Ball control  0
# 22       Total movement  0
# 23         Acceleration  0
# 24         Sprint speed  0
# 25              Agility  0
# 26            Reactions  0
# 27              Balance  0
# 28          Total power  0
# 29           Shot power  0
# 30              Jumping  0
# 31              Stamina  0
# 32             Strength  0
# 33           Long shots  1
# 34      Total mentality  0
# 35           Aggression  0
# 36        Interceptions  0
# 37        Att. Position  0
# 38               Vision  0
# 39            Penalties  0
# 40            Composure  0
# 41      Total defending  0
# 42  Defensive awareness  2
# 43      Standing tackle  0
# 44       Sliding tackle  3
# 45    Total goalkeeping  0
# 46            GK Diving  0
# 47          GK Handling  0
# 48           GK Kicking  0
# 49       GK Positioning  0

# %%
#### Remove null values
print("data before removing null value",data.shape)
data=data.dropna(axis=0)
print("data after removing null value",data.shape)
# Out:
# data before removing null value (2749, 61)
# data after removing null value (2744, 61)

# %% [markdown]
# #### Expanding the positions column

# %%
data['Best position'].value_counts().reset_index()
# Out:
#    Best position  count
# 0            CAM    540
# 1             CB    466
# 2             ST    428
# 3             CM    212
# 4            CDM    187
# 5             GK    183
# 6             RM    174
# 7             LM    123
# 8             RB    103
# 9             LB     98
# 10           LWB     67
# 11           RWB     58
# 12            RW     51
# 13            LW     40
# 14            CF     14

# %%
position_expansions = {
    "CAM": "Central Attacking Midfielder",
    "CB": "Center Back",
    "ST": "Striker",
    "CM": "Central Midfielder",
    "CDM": "Central Defensive Midfielder",
    "GK": "Goalkeeper",
    "RM": "Right Midfielder",
    "LM": "Left Midfielder",
    "RB": "Right Back",
    "LB": "Left Back",
    "LWB": "Left Wing Back",
    "RWB": "Right Wing Back",
    "RW": "Right Winger",
    "LW": "Left Winger",
    "CF": "Center Forward",
}

# %%
data['Best position expansion']=data['Best position'].replace(position_expansions)
data.head(3)
# Out:
#             name  Age  Overall rating  Potential   foot  Best overall  \
# 0     Ronaldinho   34              78         78  Right            77
# 1  O. Hutchinson   19              65         81   Left            67
# 2         Brahim   23              82         86  Right            84
#
#   Best position       Value      Wage  Release clause  ...  Base stats  \
# 0           CAM   4100000.0   45000.0             0.0  ...         377
# 1           CAM   1800000.0    3000.0       4500000.0  ...         351
# 2           CAM  43500000.0  145000.0      92400000.0  ...         409
#
#    International reputation  Pace / Diving  Shooting / Handling  \
# 0                         3             49                   72
# 1                         1             72                   54
# 2                         1             85                   74
#
#    Passing / Kicking  Dribbling / Reflexes  Defending / Pace          Team  \
# 0                 83                    84                28     Querétaro
# 1                 61                    70                44  Ipswich Town
# 2                 78                    85                31   Real Madrid
#
#       Contract       Best position expansion
# 0  2014 ~ 2016  Central Attacking Midfielder
# 1  2022 ~ 2025  Central Attacking Midfielder
# 2  2019 ~ 2027  Central Attacking Midfielder
#
# [3 rows x 62 columns]

# %% [markdown]
# #### Droping Columns

# %%
data.columns
# Out:
# Index(['name', 'Age', 'Overall rating', 'Potential', 'foot', 'Best overall',
#        'Best position', 'Value', 'Wage', 'Release clause', 'Total attacking',
#        'Crossing', 'Finishing', 'Heading accuracy', 'Short passing', 'Volleys',
#        'Total skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long passing',
#        'Ball control', 'Total movement', 'Acceleration', 'Sprint speed',
#        'Agility', 'Reactions', 'Balance', 'Total power', 'Shot power',
#        'Jumping', 'Stamina', 'Strength', 'Long shots', 'Total mentality',
#        'Aggression', 'Interceptions', 'Att. Position', 'Vision', 'Penalties',
#        'Composure', 'Total defending', 'Defensive awareness',
#        'Standing tackle', 'Sliding tackle', 'Total goalkeeping', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
#        'Total stats', 'Base stats', 'International reputation',
#        'Pace / Diving', 'Shooting / Handling', 'Passing / Kicking',
#        'Dribbling / Reflexes', 'Defending / Pace', 'Team', 'Contract',
#        'Best position expansion'],
#       dtype='object')

# %%
data=data[['name', 'Age','Team', 'Overall rating', 'Potential', 'foot', 'Best overall',
       'Best position','Best position expansion', 'Value', 'Wage', 'Release clause' ]]
data.head(3)
# Out:
#             name  Age          Team  Overall rating  Potential   foot  \
# 0     Ronaldinho   34     Querétaro              78         78  Right
# 1  O. Hutchinson   19  Ipswich Town              65         81   Left
# 2         Brahim   23   Real Madrid              82         86  Right
#
#    Best overall Best position       Best position expansion       Value  \
# 0            77           CAM  Central Attacking Midfielder   4100000.0
# 1            67           CAM  Central Attacking Midfielder   1800000.0
# 2            84           CAM  Central Attacking Midfielder  43500000.0
#
#        Wage  Release clause
# 0   45000.0             0.0
# 1    3000.0       4500000.0
# 2  145000.0      92400000.0

# %% [markdown]
# ## Export the data

# %%
data.to_excel('../processed_data/Football_players_data.xlsx',index=False)
